# %% [markdown]
# <a href="https://colab.research.google.com/github/SknyL/Face_emotion_recognition/blob/main/Train_FER_model_Valence_arousal_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1V-ZnDOA8nqpNXpi_gg18v3tDX2lSMU9F

# %%
# !unzip -q '/content/drive/MyDrive/Colab Notebooks/Emotion Recognition/croped_train.zip' -d '/content/data/'

# %% [markdown]
# ![Emotion-representation-in-the-valence-arousal-space-using-Mikels-wheel-of-emotions.ppm](data:application/octet-stream;base64,...)

# %% [markdown]
# Координаты будут [-1:1]

# %%
emotions_coord = {'happy': [.9, .2],
                  'surprise': [.4, .9],
                  'neutral': [0, 0],
                  'anger': [-.4, .8],
                  'contempt': [-.5, .25],
                  'disgust': [-.7, .5],
                  'fear': [-.1, .8],
                  'sad': [-.8, -0.4],
                  'uncertain': [0, -.3]}

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Valence от негативной к позитивной
#
# Arousal от пассивной до активной, (активность, интенсивность эмоции)

# %%
plt.subplots(figsize=(8,8))
for emotion, (v, a) in emotions_coord.items():
    plt.scatter(v, a, label=emotion, s=150)
    plt.text(v-0.1, a+0.03, emotion, size=12)
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.vlines(0, -1, 1, linestyle='dashed', lw=1)
plt.hlines(0, -1, 1, linestyle='dashed', lw=1)
plt.xlabel('Valence', size=14)
plt.ylabel('Arousal', size=14)
plt.title('Emotions in valence-arousal coords', size=17)
plt.show()

# %% [markdown]
# Вход в модель - изображение в градациях серого, размером 48х48
#
# Выход - координаты х-valence и y-arousal

# %%
import pandas as pd
import tensorflow as tf
import os

# %%
train_path = '/content/data/content/data/croped_train/'

# %%
list_to = []
for path in os.listdir(train_path):
    for img in os.listdir(os.path.join(train_path, path)):
        list_to.append([os.path.join(train_path, path, img),
                    path,
                    emotions_coord[path][0],
                    emotions_coord[path][1]])

# %%
train_dataframe = pd.DataFrame(list_to, columns=['image_path', 'emotion', 'valence', 'arousal'])

# %%
train_dataframe
# Out:
#                                               image_path emotion  valence  \
# 0      /content/data/content/data/croped_train/happy/...   happy      0.9
# 1      /content/data/content/data/croped_train/happy/...   happy      0.9
# 2      /content/data/content/data/croped_train/happy/...   happy      0.9
# 3      /content/data/content/data/croped_train/happy/...   happy      0.9
# 4      /content/data/content/data/croped_train/happy/...   happy      0.9
# ...                                                  ...     ...      ...
# 46084  /content/data/content/data/croped_train/fear/4...    fear     -0.1
# 46085  /content/data/content/data/croped_train/fear/3...    fear     -0.1
# 46086  /content/data/content/data/croped_train/fear/1...    fear     -0.1
# 46087  /content/data/content/data/croped_train/fear/2...    fear     -0.1
# 46088  /content/data/content/data/croped_train/fear/1...    fear     -0.1
#
#        arousal
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2
# ...        ...
# 46084      0.8
# 46085      0.8
# 46086      0.8
# 46087      0.8
# 46088      0.8
#
# [46089 rows x 4 columns]

# %%
import random

# %%
# featuring of valence-arousal values of given foto by adding random float within (-0.15, 0.15) of base emotion value

def randomize_valence(valence):
    """
    function return random valence value of given emotion
    """
    return valence + random.uniform(-0.05, 0.05)


def randomize_arousal(arousal):
    """
    function return random arousal value of given emotion
    """
    return arousal + random.uniform(-0.05, 0.05)

# %%
train_dataframe['valence'] = train_dataframe['valence'].apply(lambda x: randomize_valence(x))
train_dataframe['arousal'] = train_dataframe['arousal'].apply(lambda x: randomize_arousal(x))

# %%
train_dataframe
# Out:
#                                               image_path emotion   valence  \
# 0      /content/data/content/data/croped_train/happy/...   happy  0.870669
# 1      /content/data/content/data/croped_train/happy/...   happy  0.874380
# 2      /content/data/content/data/croped_train/happy/...   happy  0.903824
# 3      /content/data/content/data/croped_train/happy/...   happy  0.937865
# 4      /content/data/content/data/croped_train/happy/...   happy  0.937308
# ...                                                  ...     ...       ...
# 46084  /content/data/content/data/croped_train/fear/4...    fear -0.061442
# 46085  /content/data/content/data/croped_train/fear/3...    fear -0.145506
# 46086  /content/data/content/data/croped_train/fear/1...    fear -0.117968
# 46087  /content/data/content/data/croped_train/fear/2...    fear -0.075219
# 46088  /content/data/content/data/croped_train/fear/1...    fear -0.143721
#
#         arousal
# 0      0.169469
# 1      0.155986
# 2      0.173134
# 3      0.219614
# 4      0.152361
# ...         ...
# 46084  0.841120
# 46085  0.771623
# 46086  0.830061
# 46087  0.755131
# 46088  0.778377
#
# [46089 rows x 4 columns]

# %%
plt.subplots(figsize=(8,8))
for i in train_dataframe.sample(1000).values:
    plt.scatter(i[2], i[3], s=150)
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.vlines(0, -1, 1, linestyle='dashed', lw=1)
plt.hlines(0, -1, 1, linestyle='dashed', lw=1)
plt.xlabel('Valence', size=14)
plt.ylabel('Arousal', size=14)
plt.title('Emotions in valence-arousal coords', size=17)
plt.show()

# %%
# !mkdir /content/models
# !wget -O /content/models/class_model.py 'https://github.com/SknyL/Face_emotion_recognition/blob/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py?raw=true'
# !wget -O /content/models/va_model.py 'https://github.com/SknyL/Face_emotion_recognition/blob/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py?raw=true'
# Out:
# mkdir: cannot create directory ‘/content/models’: File exists
# --2023-03-12 15:54:14--  https://github.com/SknyL/Face_emotion_recognition/blob/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py?raw=true
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py [following]
# --2023-03-12 15:54:15--  https://github.com/SknyL/Face_emotion_recognition/raw/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py [following]
# --2023-03-12 15:54:15--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/class_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3502 (3.4K) [text/plain]
# Saving to: ‘/content/models/class_model.py’
#
# /content/models/cla 100%[===================>]   3.42K  --.-KB/s    in 0s
#
# 2023-03-12 15:54:15 (46.1 MB/s) - ‘/content/models/class_model.py’ saved [3502/3502]
#
# --2023-03-12 15:54:15--  https://github.com/SknyL/Face_emotion_recognition/blob/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py?raw=true
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py [following]
# --2023-03-12 15:54:21--  https://github.com/SknyL/Face_emotion_recognition/raw/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py [following]
# --2023-03-12 15:54:21--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2ffab713c8dfbeb421f04ed968272c8b8e994c8a/train_model/models/va_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2484 (2.4K) [text/plain]
# Saving to: ‘/content/models/va_model.py’
#
# /content/models/va_ 100%[===================>]   2.43K  --.-KB/s    in 0s
#
# 2023-03-12 15:54:21 (38.5 MB/s) - ‘/content/models/va_model.py’ saved [2484/2484]

# %%
# !mkdir /content/models/weights
# !wget -O /content/models/weights/model_class_weights.h5 'https://github.com/SknyL/Face_emotion_recognition/blob/main/train_model/models/weights/model_class_weights.h5?raw=true'
# !wget -O /content/models/weights/model_va_weights.h5 'https://github.com/SknyL/Face_emotion_recognition/blob/main/train_model/models/weights/model_va_weights.h5?raw=true'
# Out:
# mkdir: cannot create directory ‘/content/models/weights’: File exists
# --2023-03-12 15:52:53--  https://github.com/SknyL/Face_emotion_recognition/blob/main/train_model/models/weights/model_class_weights.h5?raw=true
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/main/train_model/models/weights/model_class_weights.h5 [following]
# --2023-03-12 15:52:53--  https://github.com/SknyL/Face_emotion_recognition/raw/main/train_model/models/weights/model_class_weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/train_model/models/weights/model_class_weights.h5 [following]
# --2023-03-12 15:52:54--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/train_model/models/weights/model_class_weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11202720 (11M) [application/octet-stream]
# Saving to: ‘/content/models/weights/model_class_weights.h5’
#
# /content/models/wei 100%[===================>]  10.68M  --.-KB/s    in 0.03s
#
# 2023-03-12 15:52:54 (388 MB/s) - ‘/content/models/weights/model_class_weights.h5’ saved [11202720/11202720]
#
# --2023-03-12 15:52:54--  https://github.com/SknyL/Face_emotion_recognition/blob/main/train_model/models/weights/model_va_weights.h5?raw=true
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/main/train_model/models/weights/model_va_weights.h5 [following]
# --2023-03-12 15:52:55--  https://github.com/SknyL/Face_emotion_recognition/raw/main/train_model/models/weights/model_va_weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/train_model/models/weights/model_va_weights.h5 [following]
# --2023-03-12 15:52:55--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/train_model/models/weights/model_va_weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11200160 (11M) [application/octet-stream]
# Saving to: ‘/content/models/weights/model_va_weights.h5’
#
# /content/models/wei 100%[===================>]  10.68M  --.-KB/s    in 0.03s
#
# 2023-03-12 15:52:56 (367 MB/s) - ‘/content/models/weights/model_va_weights.h5’ saved [11200160/11200160]

# %%
execfile('/content/models/class_model.py')
execfile('/content/models/va_model.py')

# %%
path_class_weights = '/content/models/weights/model_class_weights.h5'
path_va_weights = '/content/models/weights/model_va_weights.h5'

# %%
va_model = FER_va_model(path_class_model_weights=path_class_weights, path_va_model_weights=path_va_weights)
# Out:
# Model: "FER_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        1664
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 64)        102464
#
#  batch_normalization_15 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 128)       204928
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 128)       409728
#
#  batch_normalization_16 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_17 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_12 (Dense)            (None, 128)               1179776
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 9)                 1161
#
#  activation_10 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 2,787,273
# Trainable params: 2,786,121
# Non-trainable params: 1,152
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        1664
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 64)        102464
#
#  batch_normalization_15 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 128)       204928
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 128)       409728
#
#  batch_normalization_16 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_17 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_14 (Dense)            (None, 128)               1179776
#
#  batch_normalization_19 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128)               0
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 2,786,370
# Trainable params: 2,785,218
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# # Dataflow для va модели

# %%
image_size = (48,48)
batch_size = 32
train_path = '/content/data/content/data/croped_train'

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                                rotation_range=15,
                                                                width_shift_range=0.05,
                                                                height_shift_range=0.05,
                                                                horizontal_flip=True,
                                                                validation_split=0.2,
                                                                fill_mode='nearest')

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          validation_split = 0.2)

# %%
train_dataflow = train_datagen.flow_from_dataframe(train_dataframe,
                                                    x_col='image_path',
                                                    y_col=['valence','arousal'],
                                                    target_size=image_size,
                                                    batch_size=batch_size,
                                                    color_mode='grayscale',
                                                    class_mode='raw',
                                                    shuffle=True,
                                                    subset='training',
                                                    interpolation='bilinear',
                                                    keep_aspect_ratio=True)

valid_dataflow = valid_datagen.flow_from_dataframe(train_dataframe,
                                                    x_col='image_path',
                                                    y_col=['valence','arousal'],
                                                    target_size=image_size,
                                                    batch_size=batch_size,
                                                    color_mode='grayscale',
                                                    class_mode='raw',
                                                    shuffle=True,
                                                    subset='validation',
                                                    interpolation='bilinear',
                                                    keep_aspect_ratio=True)
# Out:
# Found 36872 validated image filenames.
# Found 9217 validated image filenames.

# %%
mcp = tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/Emotion Recognition/v2_model/final_weights/model_va_weights.h5',
                                       monitor='val_mean_absolute_error',
                                       verbose=1,
                                       save_best_only=False,
                                       save_weights_only=True,
                                       save_freq='epoch',
                                       mode='min')

# %%
my_optimiser = tf.keras.optimizers.Adam(learning_rate=0.001,name='Adam')

va_model.compile(loss='mse', metrics=['mean_absolute_error'], optimizer=my_optimiser)
va_model.fit(train_dataflow, 
             validation_data=valid_dataflow, 
             epochs=30, 
             steps_per_epoch=2*len(train_dataflow),
             callbacks=[mcp])

# %% [markdown]
# Посмотреть слои в сохраненной модели

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
import matplotlib.pyplot as plt

# %%
emotions_coord = {'happy': [.9, .2],
                          'surprise': [.4, .9],
                          'neutral': [0, 0],
                          'anger': [-.4, .8],
                          'contempt': [-.5, .25],
                          'disgust': [-.7, .5],
                          'fear': [-.1, .8],
                          'sad': [-.8, -0.4],
                          'uncertain': [0, -.3]}
emotions = spatial.KDTree(list(emotions_coord.values()))

# %%
imgs, label = valid_dataflow.next()

rows = 6
cols = 6
count = 0

fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(18,18))
for i in range(rows):
    for j in range(cols):        
        if count < len(imgs):
            axes[i, j].axis("off")
            axes[i, j].imshow(imgs[count], cmap='gray', vmin=0, vmax=1)
            emotion_predict, coords = va_model.get_emotion(imgs[count])
            emotion_number = int(emotions.query(coords)[1])
            emotion_real = list(emotions_coord.keys())[emotion_number]
            axes[i, j].set_title(f'real_label:{emotion_real} \n predict: {emotion_predict}')
            count+=1
