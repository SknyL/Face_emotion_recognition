# %% [markdown]
# <a href="https://colab.research.google.com/github/SknyL/Face_emotion_recognition/blob/main/Train_FER_model_Valence_arousal_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown 1V-ZnDOA8nqpNXpi_gg18v3tDX2lSMU9F

# %%
# !unzip -q '/content/drive/MyDrive/Colab Notebooks/Emotion Recognition/croped_train.zip' -d '/content/data/'

# %% [markdown]
# ![Emotion-representation-in-the-valence-arousal-space-using-Mikels-wheel-of-emotions.ppm](data:application/octet-stream;base64,...)

# %% [markdown]
# Координаты будут [-1:1]

# %%
emotions_coord = {'happy': [.9, .2],
                  'surprise': [.4, .9],
                  'neutral': [0, 0],
                  'anger': [-.4, .8],
                  'contempt': [-.5, .25],
                  'disgust': [-.7, .5],
                  'fear': [-.1, .8],
                  'sad': [-.8, -0.4],
                  'uncertain': [0, -.3]}

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Valence от негативной к позитивной
#
# Arousal от пассивной до активной, (активность, интенсивность эмоции)

# %%
plt.subplots(figsize=(8,8))
for emotion, (v, a) in emotions_coord.items():
    plt.scatter(v, a, label=emotion, s=150)
    plt.text(v-0.1, a+0.03, emotion, size=12)
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.vlines(0, -1, 1, linestyle='dashed', lw=1)
plt.hlines(0, -1, 1, linestyle='dashed', lw=1)
plt.xlabel('Valence', size=14)
plt.ylabel('Arousal', size=14)
plt.title('Emotions in valence-arousal coords', size=17)
plt.show()

# %% [markdown]
# Вход в модель - изображение в градациях серого, размером 48х48
#
# Выход - координаты х-valence и y-arousal

# %%
import pandas as pd
import tensorflow as tf
import os

# %%
train_path = '/content/data/content/data/croped_train/'

# %%
list_to = []
for path in os.listdir(train_path):
    for img in os.listdir(os.path.join(train_path, path)):
        list_to.append([os.path.join(train_path, path, img),
                    path,
                    emotions_coord[path][0],
                    emotions_coord[path][1]])

# %%
train_dataframe = pd.DataFrame(list_to, columns=['image_path', 'emotion', 'valence', 'arousal'])

# %%
train_dataframe
# Out:
#                                               image_path emotion  valence  \
# 0      /content/data/content/data/croped_train/happy/...   happy      0.9
# 1      /content/data/content/data/croped_train/happy/...   happy      0.9
# 2      /content/data/content/data/croped_train/happy/...   happy      0.9
# 3      /content/data/content/data/croped_train/happy/...   happy      0.9
# 4      /content/data/content/data/croped_train/happy/...   happy      0.9
# ...                                                  ...     ...      ...
# 46084  /content/data/content/data/croped_train/fear/4...    fear     -0.1
# 46085  /content/data/content/data/croped_train/fear/3...    fear     -0.1
# 46086  /content/data/content/data/croped_train/fear/1...    fear     -0.1
# 46087  /content/data/content/data/croped_train/fear/2...    fear     -0.1
# 46088  /content/data/content/data/croped_train/fear/1...    fear     -0.1
#
#        arousal
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2
# ...        ...
# 46084      0.8
# 46085      0.8
# 46086      0.8
# 46087      0.8
# 46088      0.8
#
# [46089 rows x 4 columns]

# %%
import random

# %%
# featuring of valence-arousal values of given foto by adding random float within (-0.15, 0.15) of base emotion value

def randomize_valence(valence):
    """
    function return random valence value of given emotion
    """
    return valence + random.uniform(-0.05, 0.05)


def randomize_arousal(arousal):
    """
    function return random arousal value of given emotion
    """
    return arousal + random.uniform(-0.05, 0.05)

# %%
train_dataframe['valence'] = train_dataframe['valence'].apply(lambda x: randomize_valence(x))
train_dataframe['arousal'] = train_dataframe['arousal'].apply(lambda x: randomize_arousal(x))

# %%
train_dataframe
# Out:
#                                               image_path emotion   valence  \
# 0      /content/data/content/data/croped_train/happy/...   happy  0.935102
# 1      /content/data/content/data/croped_train/happy/...   happy  0.855707
# 2      /content/data/content/data/croped_train/happy/...   happy  0.925096
# 3      /content/data/content/data/croped_train/happy/...   happy  0.870915
# 4      /content/data/content/data/croped_train/happy/...   happy  0.894032
# ...                                                  ...     ...       ...
# 46084  /content/data/content/data/croped_train/fear/4...    fear -0.120928
# 46085  /content/data/content/data/croped_train/fear/3...    fear -0.138745
# 46086  /content/data/content/data/croped_train/fear/1...    fear -0.115547
# 46087  /content/data/content/data/croped_train/fear/2...    fear -0.050406
# 46088  /content/data/content/data/croped_train/fear/1...    fear -0.079552
#
#         arousal
# 0      0.227231
# 1      0.185367
# 2      0.198936
# 3      0.157231
# 4      0.221605
# ...         ...
# 46084  0.834651
# 46085  0.820462
# 46086  0.756950
# 46087  0.834106
# 46088  0.766235
#
# [46089 rows x 4 columns]

# %%
plt.subplots(figsize=(8,8))
for i in train_dataframe.sample(1000).values:
    plt.scatter(i[2], i[3], s=150)
plt.xlim(-1,1)
plt.ylim(-1,1)
plt.vlines(0, -1, 1, linestyle='dashed', lw=1)
plt.hlines(0, -1, 1, linestyle='dashed', lw=1)
plt.xlabel('Valence', size=14)
plt.ylabel('Arousal', size=14)
plt.title('Emotions in valence-arousal coords', size=17)
plt.show()

# %%
image_size = (48,48)
batch_size = 32
train_path = '/content/data/content/data/croped_train'

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                                rotation_range=15,
                                                                width_shift_range=0.05,
                                                                height_shift_range=0.05,
                                                                horizontal_flip=True,
                                                                validation_split=0.2,
                                                                fill_mode='nearest')

valid_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          validation_split = 0.2)

# %%
# !wget -O /content/models/va_model.py 'https://github.com/SknyL/Face_emotion_recognition/blob/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py?raw=true'
# !wget -O /content/models/class_model.py 'https://github.com/SknyL/Face_emotion_recognition/blob/c03b458c383b386434036087abd441858320a2bb/class_model.py?raw=true'
# Out:
# --2023-03-11 19:49:12--  https://github.com/SknyL/Face_emotion_recognition/blob/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py?raw=true
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py [following]
# --2023-03-11 19:49:12--  https://github.com/SknyL/Face_emotion_recognition/raw/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py [following]
# --2023-03-11 19:49:13--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/2fcd5f3e74f363147e6a5388ef85696c8231037f/va_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2513 (2.5K) [text/plain]
# Saving to: ‘/content/va_model.py’
#
# /content/va_model.p 100%[===================>]   2.45K  --.-KB/s    in 0s
#
# 2023-03-11 19:49:13 (41.4 MB/s) - ‘/content/va_model.py’ saved [2513/2513]
#
# --2023-03-11 19:49:13--  https://github.com/SknyL/Face_emotion_recognition/blob/c03b458c383b386434036087abd441858320a2bb/class_model.py?raw=true
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/c03b458c383b386434036087abd441858320a2bb/class_model.py [following]
# --2023-03-11 19:49:13--  https://github.com/SknyL/Face_emotion_recognition/raw/c03b458c383b386434036087abd441858320a2bb/class_model.py
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/c03b458c383b386434036087abd441858320a2bb/class_model.py [following]
# --2023-03-11 19:49:13--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/c03b458c383b386434036087abd441858320a2bb/class_model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3585 (3.5K) [text/plain]
# Saving to: ‘/content/class_model.py’
#
# /content/class_mode 100%[===================>]   3.50K  --.-KB/s    in 0s
#
# 2023-03-11 19:49:13 (52.5 MB/s) - ‘/content/class_model.py’ saved [3585/3585]

# %%
# !mkdir /content/model/weights
# !wget -O /content/models/weights/model_class_weights.h5 'https://github.com/SknyL/Face_emotion_recognition/blob/main/model_class_weights.h5?raw=true'
# !wget -O /content/models/weights/model_va_weights.h5 'https://github.com/SknyL/Face_emotion_recognition/blob/main/model_va_weights.h5?raw=true'
# Out:
# --2023-03-11 19:59:30--  https://github.com/SknyL/Face_emotion_recognition/blob/main/model_class_weights.h5?raw=true
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/main/model_class_weights.h5 [following]
# --2023-03-11 19:59:30--  https://github.com/SknyL/Face_emotion_recognition/raw/main/model_class_weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/model_class_weights.h5 [following]
# --2023-03-11 19:59:30--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/model_class_weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11202720 (11M) [application/octet-stream]
# Saving to: ‘/content/weights/model_class_weights.h5’
#
# /content/weights/mo 100%[===================>]  10.68M  --.-KB/s    in 0.06s
#
# 2023-03-11 19:59:30 (193 MB/s) - ‘/content/weights/model_class_weights.h5’ saved [11202720/11202720]
#
# --2023-03-11 19:59:30--  https://github.com/SknyL/Face_emotion_recognition/blob/main/model_va_weights.h5?raw=true
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/SknyL/Face_emotion_recognition/raw/main/model_va_weights.h5 [following]
# --2023-03-11 19:59:30--  https://github.com/SknyL/Face_emotion_recognition/raw/main/model_va_weights.h5
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/model_va_weights.h5 [following]
# --2023-03-11 19:59:31--  https://raw.githubusercontent.com/SknyL/Face_emotion_recognition/main/model_va_weights.h5
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11200160 (11M) [application/octet-stream]
# Saving to: ‘/content/weights/model_va_weights.h5’
#
# /content/weights/mo 100%[===================>]  10.68M  --.-KB/s    in 0.05s
#
# 2023-03-11 19:59:31 (218 MB/s) - ‘/content/weights/model_va_weights.h5’ saved [11200160/11200160]

# %%
execfile('/content/models/class_model.py')
execfile('/content/models/va_model.py')

# %%
path_class_weights = '/content/weights/model_class_weights.h5'
path_va_weights = '/content/weights/model_va_weights.h5'

# %%
va_model = FER_va_model(path_class_model_weights=path_class_weights, path_va_model_weights=path_va_weights)
# Out:
# Model: "FER_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        1664
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 64)        102464
#
#  batch_normalization_15 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 128)       204928
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 128)       409728
#
#  batch_normalization_16 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_17 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_12 (Dense)            (None, 128)               1179776
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_9 (Activation)   (None, 128)               0
#
#  dropout_18 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 9)                 1161
#
#  activation_10 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 2,787,273
# Trainable params: 2,786,121
# Non-trainable params: 1,152
# _________________________________________________________________
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 64)        1664
#
#  conv2d_19 (Conv2D)          (None, 48, 48, 64)        102464
#
#  batch_normalization_15 (Bat  (None, 48, 48, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 64)       0
#  2D)
#
#  dropout_15 (Dropout)        (None, 24, 24, 64)        0
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 128)       204928
#
#  conv2d_21 (Conv2D)          (None, 24, 24, 128)       409728
#
#  batch_normalization_16 (Bat  (None, 24, 24, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_16 (Dropout)        (None, 12, 12, 128)       0
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 256)       295168
#
#  conv2d_23 (Conv2D)          (None, 12, 12, 256)       590080
#
#  batch_normalization_17 (Bat  (None, 12, 12, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 256)        0
#  g2D)
#
#  dropout_17 (Dropout)        (None, 6, 6, 256)         0
#
#  flatten_3 (Flatten)         (None, 9216)              0
#
#  dense_14 (Dense)            (None, 128)               1179776
#
#  batch_normalization_19 (Bat  (None, 128)              512
#  chNormalization)
#
#  activation_11 (Activation)  (None, 128)               0
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_15 (Dense)            (None, 2)                 258
#
# =================================================================
# Total params: 2,786,370
# Trainable params: 2,785,218
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# # Dataflow для va модели

# %%
train_dataflow = train_datagen.flow_from_dataframe(train_dataframe,
                                                    x_col='image_path',
                                                    y_col=['valence','arousal'],
                                                    target_size=image_size,
                                                    batch_size=batch_size,
                                                    color_mode='grayscale',
                                                    class_mode='raw',
                                                    shuffle=True,
                                                    subset='training',
                                                    interpolation='bilinear',
                                                    keep_aspect_ratio=True)

valid_dataflow = valid_datagen.flow_from_dataframe(train_dataframe,
                                                    x_col='image_path',
                                                    y_col=['valence','arousal'],
                                                    target_size=image_size,
                                                    batch_size=batch_size,
                                                    color_mode='grayscale',
                                                    class_mode='raw',
                                                    shuffle=True,
                                                    subset='validation',
                                                    interpolation='bilinear',
                                                    keep_aspect_ratio=True)
# Out:
# Found 36872 validated image filenames.
# Found 9217 validated image filenames.

# %%
mcp = tf.keras.callbacks.ModelCheckpoint('/content/drive/MyDrive/Colab Notebooks/Emotion Recognition/v2_model/final_weights/model_va_weights.h5',
                                       monitor='val_mean_absolute_error',
                                       verbose=1,
                                       save_best_only=False,
                                       save_weights_only=True,
                                       save_freq='epoch',
                                       mode='min')

# %%
my_optimiser = tf.keras.optimizers.Adam(learning_rate=0.001,name='Adam')

va_model.compile(loss='mse', metrics=['mean_absolute_error'], optimizer=my_optimiser)
va_model.fit(train_dataflow, validation_data=valid_dataflow, epochs=30, callbacks=[mcp])

# %% [markdown]
# Посмотреть слои в сохраненной модели

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_path = '/content/data/content/data/croped_train/happy/20.jpg'
img = cv2.imread(img_path)
img_pred = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_pred = img_pred / 255.
img_pred = cv2.resize(img_pred, (48,48))
img_pred = np.expand_dims(img_pred, -1)
emotion_name, prediction = va_model.get_emotion(img_pred)
img = cv2.resize(img, (256,256))
img = cv2.putText(img, f'{prediction}', (5, 225), 
                  cv2.FONT_HERSHEY_SIMPLEX, 
                  0.5, (0, 0, 255), 1, cv2.LINE_AA)
img = cv2.putText(img, f'{emotion_name}', (5, 250), 
                  cv2.FONT_HERSHEY_SIMPLEX, 
                  0.7, (0, 0, 255), 1, cv2.LINE_AA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F094C088970>
